# %%
from src.import_file import *
from src import data_read
from src import high_dim_feature_with_labels
from src import PCA_self
from src import LDA_self
from sklearn.decomposition import PCA
'''Check results with PCA inbuilt'''
img_list,img_targets=data_read.get_data_(train=True)
N=len(img_targets)
X,Y=high_dim_feature_with_labels.norm_highx_y_(img_list,img_targets)

'K is the lower dimension'
for K in range(2,20):
    X_low=PCA_self.pca_scratch_high_dim(X,K,N)
    pca = PCA(n_components=K)
    pca.fit_transform(X)
    X_low_lib=pca.transform(X)
    print(f'{K}components')
    LDA_self.FiscLDA(X_low,Y)
    print(f'{K}components library')
    LDA_self.FiscLDA(X_low_lib,Y)
# Out:
# 2components library
# 3components library
# 4components library
# 5components library
# 6components library
# 7components library
# 8components library
# 9components library
# 10components library
# 11components library
# 12components library
# 13components library
# 14components library
# 15components library
# 16components library
# 17components library
# 18components library
# 19components library

# %%
from src.import_file import *
from src import data_read
from src import high_dim_feature_with_labels
from src import PCA_self
from src import LDA_self
from sklearn.decomposition import PCA
'''Check results with PCA inbuilt'''
img_list,img_targets=data_read.get_data_(train=True)
N=len(img_targets)
X,Y=high_dim_feature_with_labels.norm_highx_y_(img_list,img_targets)

'K is the lower dimension'
for K in range(2,20):
    X_low=PCA_self.pca_scratch_high_dim(X,K,N)
    print(f'{K}components')
    LDA_self.FiscLDA(X_low,Y)

# %%
from src.import_file import *
from src import data_read
from src import high_dim_feature_with_labels
from src import PCA_file
from src import LDA_self
from src import PCA_self
from sklearn.decomposition import PCA
'''Check results with PCA inbuilt'''
img_list,img_targets=data_read.get_data_(train=True)
N=len(img_targets)
X,Y=high_dim_feature_with_labels.norm_highx_y_(img_list,img_targets)

'K is the lower dimension'
for K in range(2,20):
    mypca=PCA_file.PCA_scratch(n_components=K)
    X_low=mypca.fit_predict(X)
    X_low_fn=PCA_self.pca_scratch_high_dim(X,K,N)
    print(f'{K}components class')
    LDA_self.FiscLDA(X_low,Y)
    print(f'{K}components function')
    LDA_self.FiscLDA(X_low_fn,Y)
# Out:
# 2components class
# 2components function
# 3components class
# 3components function
# 4components class
# 4components function
# 5components class
# 5components function
# 6components class
# 6components function
# 7components class
# 7components function
# 8components class
# 8components function
# 9components class
# 9components function
# 10components class
# 10components function
# 11components class
# 11components function
# 12components class
# 12components function
# 13components class
# 13components function
# 14components class
# 14components function
# 15components class
# 15components function
# 16components class
# 16components function
# 17components class
# 17components function
# 18components class
# 18components function
# 19components class
# 19components function

# %%
pca.components_.shape
# Out:
# (19, 10201)

# %%
pca.mean_.shape
# Out:
# (10201,)

# %%
X.shape
# Out:
# (20, 10201)

# %%
X_low.shape
# Out:
# (20, 19)

# %%
X_low[0]
# Out:
# array([-5.20109637e+03,  1.51431966e+03, -6.23638011e+01, -1.51882640e+03,
#        -1.66374430e+02,  1.33737649e+03, -1.07596592e+03, -4.04672484e+02,
#         4.25392126e-05,  8.13433020e+02,  8.02790515e+02,  7.52176834e+01,
#        -1.03121413e+02, -1.27547012e+02, -1.21980106e+01])

# %%
# pca.fit_transform(X)

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(X, Y)
# Out:
# SVC()
