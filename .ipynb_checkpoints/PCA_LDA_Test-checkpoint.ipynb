# %%
from src.import_file import *
from src import data_read
from src import high_dim_feature_with_labels
from src import PCA_file
from src import LDA_self
from sklearn.decomposition import PCA
'''Check results with PCA inbuilt'''

'''Get train data'''
img_list,img_targets=data_read.get_data_(train=True)
N_train=len(img_targets)
X,Y=high_dim_feature_with_labels.norm_highx_y_(img_list,img_targets)

'''Get test data'''
img_list,img_targets=data_read.get_data_(train=False)
N_test=len(img_targets)
Xtest,Ytest=high_dim_feature_with_labels.norm_highx_y_(img_list,img_targets)


'K is the lower dimension'
for K in range(2,20):
    libpca = PCA(n_components=K)
    X_low_lib=libpca.fit(X)
    X_low_lib_test=libpca.transform(Xtest)
    
    mypca=PCA_file.PCA_scratch(n_components=K)
    X_low_my=mypca.fit(X)
    X_low_my_test=mypca.predict(Xtest)
    
    print(f'{K}components mine')
    LDA_self.FiscLDA(X_low_my_test,Ytest)
    print(f'{K}components library')
    LDA_self.FiscLDA(X_low_lib_test,Ytest)
# Out:
# 2components mine
# 2components library
# 3components mine
# 3components library
# 4components mine
# 4components library
# 5components mine
# 5components library
# 6components mine
# 6components library
# 7components mine
# 7components library
# 8components mine
# 8components library
# 9components mine
# 9components library
# 10components mine
# 10components library
# 11components mine
# 11components library
# 12components mine
# 12components library
# 13components mine
# 13components library
# 14components mine
# 14components library
# 15components mine
# 15components library
# 16components mine
# 16components library
# 17components mine
# 17components library
# 18components mine
# 18components library
# 19components mine
# 19components library
